# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Read the datasset
df=pd.read_csv("stud.csv")

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# Data checks to perform
# 1.Check missing values
# 2.Check duplicates
# 3.check data type
# 4.Check the number of unique values in each of the columns
# 5.Check statistics or dataset
# 6.Check Various categories present in the different cateegorical form

# %%
#check missing values
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
# Alwayas after checking for the missing values write down thee observation becoz client obviously wants ony ur observation

# %%
#So the observation is that their is no missing values in the dataset

# %%
#EDA is all about observation and insights

# %%
#Other way to check null values
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
#How to check the duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#SO the observation is that their is no duplicate values in the dataset

# %%
#check the datatypes of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
##Checking the number of unique values of the each column
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
#Eg heere thee gender the has 2 unique values male and female

# %%
#Check the statistics of the dataset
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
'''Insights or observation
1.From the above description of the numerical data, all mean values are very close to each otherbetween 66 to 69
2.All the standard deviation are very close between 14.6 to 15.19
3.While their is a min of 0 for maths, others are having 17 and 10 values'''
# Out:
# 'Insights or observation\n1.From the above description of the numerical data, all mean values are very close to each otherbetween 66 to 69\n2.All the standard deviation are very close between 14.6 to 15.19\n3.While their is a min of 0 for mathematics, others are having 17 and 10 values'

# %%
#Explore more about the data
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Let us make seperation as numerical and categorical values
numerical_features=[feature for feature in df.columns if df[feature].dtype!='O']
categorical_feature=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
# Above what we did is the list comprehension

# %%
# suppose i want to c all the features in the catergories, it displays thee features
[feature for feature in df.columns]
# suppose i want only the numerical features and i dont want the categorical 
# so i ll write the if condtion to check if its not equal to object "O"
# So we ll get the numerical features
# Out:
# ['gender',
#  'race_ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course',
#  'math_score',
#  'reading_score',
#  'writing_score']

# %%
[feature for feature in df.columns if df[feature].dtype!='O']
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
numerical_features
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
categorical_feature
# Out:
# ['gender',
#  'race_ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course']

# %%
## Aggregate the total score with mean

df['total_score']=(df['math_score']+df['reading_score']+df['writing_score'])
df['average']=df['total_score']/3
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
#Explore more about visualization

# %%
fig,axis=plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)#121 is 1st row 2nd column i want to display
sns.histplot(data=df,x="average",bins=30,kde=True,color="r")#bins=30 is default

plt.subplot(122)#121 is 1st row 2nd column i want to display
sns.histplot(data=df,x="average",bins=30,kde=True,hue="gender")
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
#Insights 
# Here female students tend to study perform well than male students

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='lunch')
plt.show()

# %%
# Insights
# Standard lunch help studeents peerform well in exams

# %%
# For both male and female standard lunch helps to perform well

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='parental_level_of_education')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='parental_level_of_education')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='parental_level_of_education')
plt.show()

# %%
# #####  Insights
# - In general parent's education don't help student perform well in exam.
# - 2nd plot shows that parent's whose education is of associate's degree or master's degree their male child tend to perform well in exam
# - 3rd plot we can see there is no effect of parent's education on female students.

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='race_ethnicity')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='race_ethnicity')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='race_ethnicity')
plt.show()

# %%
# #####  Insights
# - Students of group A and group B tends to perform poorly in exam.
# - Students of group A and group B tends to perform poorly in exam irrespective of whether they are male or female

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sns.heatmap(df.corr(),annot=True)
#
# File c:\Users\vaish\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\vaish\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
# ...
